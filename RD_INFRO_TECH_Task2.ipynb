# %%
import pandas as pd
df = pd.read_excel("customer_data.xlsx")
print(df.head())
print("Rows & Columns:",df.shape)

import sqlite3
import pandas as pd
conn = sqlite3.connect("customer_database.db")
query = "SELECT *FROM customers"
df = pd.read_sql(query, conn)
print(df.head())
conn.close()
# Out:
#    customer_id  age  gender  monthly_charges  tenure contract_type  churn
# 0            1   28    Male              499      12       Monthly      1
# 1            2   35  Female              799      24        Yearly      0
# 2            3   42    Male              999      36        Yearly      0
# 3            4   30  Female              299       6       Monthly      1
# 4            5   25    Male              399      10       Monthly      1
# Rows & Columns: (8, 7)
#    customer_id  age  gender  monthly_charges  tenure contract_type  churn
# 0            1   28    Male            499.0      12       Monthly      1
# 1            2   35  Female            799.0      24        Yearly      0
# 2            3   42    Male            999.0      36        Yearly      0
# 3            4   30  Female            299.0       6       Monthly      1
# 4            5   25    Male            399.0      10       Monthly      1

# %%
business_problem = "will the customer churn?"
ml_objective = "predict whether a customer will churn or not"
ml_task_type = "Binary Classification"
target_variable = "Churn"
print("Business Problem:",business_problem)
print("ML Objective:",ml_objective)
print("ML Task Type:",ml_task_type)
print("Target Variable:",target_variable)
# Out:
# Business Problem: will the customer churn?
# ML Objective: predict whether a customer will churn or not
# ML Task Type: Binary Classification
# Target Variable: Churn
